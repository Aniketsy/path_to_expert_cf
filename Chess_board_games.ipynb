# %% [markdown]
# ![Screenshot 2025-09-29 220119.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2025-09-29 214703.png](data:image/png;base64,...)

# %%
n = int(input().strip())
for k in range(1, n+1):
  total = k*k*(k*k-1)//2
  attacking = 4*(k-1)*(k-2)
  non_attacking = total - attacking
  print(non_attacking)
